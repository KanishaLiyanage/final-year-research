# %%
import re
import csv
import nltk
import keras
import string
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from nltk import FreqDist
from termcolor import colored
import matplotlib.pyplot as plt
from nltk.tokenize import word_tokenize
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Sequential
from mlxtend.plotting import plot_confusion_matrix
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score
from tensorflow.keras.layers import LSTM, Dense, Dropout, GlobalMaxPooling1D, Bidirectional, Embedding

#Classifiers
from sklearn.naive_bayes import MultinomialNB
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
train_set_path = '/kaggle/input/ag-news-sinhala/ag_news_sinhala/train.csv'
test_set_path = '/kaggle/input/ag-news-sinhala/ag_news_sinhala/test.csv'

# %%
stop_words = '/kaggle/input/stop-words/stop words.txt'
stem_dictionary = '/kaggle/input/stem-dictionary/stem_dictionary.txt'

# %%
train_set = pd.read_csv(train_set_path)
test_set = pd.read_csv(test_set_path)

# %%
# Concatenate train and test data
df = pd.concat([train_set, test_set], ignore_index=True)

# Save the combined data to a new CSV file
df.to_csv('combined.csv', index=False)

# %%
df.head()
# Out:
#    Unnamed: 0  Class Index                                    Title (English)  \
# 0           0            3  Wall St. Bears Claw Back Into the Black (Reuters)
# 1           1            3  Carlyle Looks Toward Commercial Aerospace (Reu...
# 2           2            3    Oil and Economy Cloud Stocks' Outlook (Reuters)
# 3           3            3  Iraq Halts Oil Exports from Main Southern Pipe...
# 4           4            3  Oil prices soar to all-time record, posing new...
#
#                                Description (English)  \
# 0  Reuters - Short-sellers, Wall Street's dwindli...
# 1  Reuters - Private investment firm Carlyle Grou...
# 2  Reuters - Soaring crude prices plus worries\ab...
# 3  Reuters - Authorities have halted oil export\f...
# 4  AFP - Tearaway world oil prices, toppling reco...
#
#                                      Title (Sinhala)  \
# 0    වෝල් වීදිය නැවතත් ධනාත්මක ආර්ථිකයක් ලබා ගත්තේය.
# 1      කාර්ලයිල් වාණිජ අභ්‍යවකාශය දෙස බලයි (රොයිටර්)
# 2                                    තෙල් සහ ආර්ථිකය
# 3  ඉරාකය ප්‍රධාන දකුණු නල මාර්ගයෙන් (රොයිටර්) තෙල...
# 4  එක්සත් ජනපද ආර්ථිකයට (AFP) නව තර්ජනයක් එල්ල කර...
#
#                                Description (Sinhala)
# 0  නිව් යෝර්ක් (රොයිටර්) - කෙටි විකුණුම්කරුවන්, ව...
# 1  රොයිටර් - පුද්ගලික ආයෝජන සමාගමක් වන Carlyle Gr...
# 2  රොයිටර් - බොරතෙල් මිල ඉහළ යාම සහ ආර්ථිකය පිළිබ...
# 3  රොයිටර් - කැරලිකාර මිලීෂියාවකට යටිතල පහසුකම්වල...
# 4  AFP - ඉරාක ලෝක තෙල් මිල, වාර්තා පෙරලීම සහ මුදල...

# %%
df = df.drop(['Unnamed: 0', 'Title (English)', 'Description (English)'], axis=1).copy()

# %%
df.head()
# Out:
#    Class Index                                    Title (Sinhala)  \
# 0            3    වෝල් වීදිය නැවතත් ධනාත්මක ආර්ථිකයක් ලබා ගත්තේය.
# 1            3      කාර්ලයිල් වාණිජ අභ්‍යවකාශය දෙස බලයි (රොයිටර්)
# 2            3                                    තෙල් සහ ආර්ථිකය
# 3            3  ඉරාකය ප්‍රධාන දකුණු නල මාර්ගයෙන් (රොයිටර්) තෙල...
# 4            3  එක්සත් ජනපද ආර්ථිකයට (AFP) නව තර්ජනයක් එල්ල කර...
#
#                                Description (Sinhala)
# 0  නිව් යෝර්ක් (රොයිටර්) - කෙටි විකුණුම්කරුවන්, ව...
# 1  රොයිටර් - පුද්ගලික ආයෝජන සමාගමක් වන Carlyle Gr...
# 2  රොයිටර් - බොරතෙල් මිල ඉහළ යාම සහ ආර්ථිකය පිළිබ...
# 3  රොයිටර් - කැරලිකාර මිලීෂියාවකට යටිතල පහසුකම්වල...
# 4  AFP - ඉරාක ලෝක තෙල් මිල, වාර්තා පෙරලීම සහ මුදල...

# %%
labels = ['World', 'Sports', 'Business & Economics', 'Science & Technology']

# %%
def clean_text(text):
    tokens = nltk.word_tokenize(text)
    regex = re.compile(u'[^\u0D80-\u0DFF]', re.UNICODE)
    tokens = [regex.sub('', w) for w in tokens]
    tokens = [c for c in tokens if c not in string.punctuation]
    return tokens

# %%
df['Cleaned Title'] = df['Title (Sinhala)'].apply(lambda x: clean_text(x))
df.head()
# Out:
#    Class Index                                    Title (Sinhala)  \
# 0            3    වෝල් වීදිය නැවතත් ධනාත්මක ආර්ථිකයක් ලබා ගත්තේය.
# 1            3      කාර්ලයිල් වාණිජ අභ්‍යවකාශය දෙස බලයි (රොයිටර්)
# 2            3                                    තෙල් සහ ආර්ථිකය
# 3            3  ඉරාකය ප්‍රධාන දකුණු නල මාර්ගයෙන් (රොයිටර්) තෙල...
# 4            3  එක්සත් ජනපද ආර්ථිකයට (AFP) නව තර්ජනයක් එල්ල කර...
#
#                                Description (Sinhala)  \
# 0  නිව් යෝර්ක් (රොයිටර්) - කෙටි විකුණුම්කරුවන්, ව...
# 1  රොයිටර් - පුද්ගලික ආයෝජන සමාගමක් වන Carlyle Gr...
# 2  රොයිටර් - බොරතෙල් මිල ඉහළ යාම සහ ආර්ථිකය පිළිබ...
# 3  රොයිටර් - කැරලිකාර මිලීෂියාවකට යටිතල පහසුකම්වල...
# 4  AFP - ඉරාක ලෝක තෙල් මිල, වාර්තා පෙරලීම සහ මුදල...
#
#                                        Cleaned Title
# 0  [වෝල්, වීදිය, නැවතත්, ධනාත්මක, ආර්ථිකයක්, ලබා,...
# 1  [කාර්ලයිල්, වාණිජ, අභ්යවකාශය, දෙස, බලයි, රොයිටර්]
# 2                                [තෙල්, සහ, ආර්ථිකය]
# 3  [ඉරාකය, ප්රධාන, දකුණු, නල, මාර්ගයෙන්, රොයිටර්,...
# 4  [එක්සත්, ජනපද, ආර්ථිකයට, නව, තර්ජනයක්, එල්ල, ක...

# %%
df['Cleaned Description'] = df['Description (Sinhala)'].apply(lambda x: clean_text(x))
df.head()
# Out:
#    Class Index                                    Title (Sinhala)  \
# 0            3    වෝල් වීදිය නැවතත් ධනාත්මක ආර්ථිකයක් ලබා ගත්තේය.
# 1            3      කාර්ලයිල් වාණිජ අභ්‍යවකාශය දෙස බලයි (රොයිටර්)
# 2            3                                    තෙල් සහ ආර්ථිකය
# 3            3  ඉරාකය ප්‍රධාන දකුණු නල මාර්ගයෙන් (රොයිටර්) තෙල...
# 4            3  එක්සත් ජනපද ආර්ථිකයට (AFP) නව තර්ජනයක් එල්ල කර...
#
#                                Description (Sinhala)  \
# 0  නිව් යෝර්ක් (රොයිටර්) - කෙටි විකුණුම්කරුවන්, ව...
# 1  රොයිටර් - පුද්ගලික ආයෝජන සමාගමක් වන Carlyle Gr...
# 2  රොයිටර් - බොරතෙල් මිල ඉහළ යාම සහ ආර්ථිකය පිළිබ...
# 3  රොයිටර් - කැරලිකාර මිලීෂියාවකට යටිතල පහසුකම්වල...
# 4  AFP - ඉරාක ලෝක තෙල් මිල, වාර්තා පෙරලීම සහ මුදල...
#
#                                        Cleaned Title  \
# 0  [වෝල්, වීදිය, නැවතත්, ධනාත්මක, ආර්ථිකයක්, ලබා,...
# 1  [කාර්ලයිල්, වාණිජ, අභ්යවකාශය, දෙස, බලයි, රොයිටර්]
# 2                                [තෙල්, සහ, ආර්ථිකය]
# 3  [ඉරාකය, ප්රධාන, දකුණු, නල, මාර්ගයෙන්, රොයිටර්,...
# 4  [එක්සත්, ජනපද, ආර්ථිකයට, නව, තර්ජනයක්, එල්ල, ක...
#
#                                  Cleaned Description
# 0  [නිව්, යෝර්ක්, රොයිටර්, කෙටි, විකුණුම්කරුවන්, ...
# 1  [රොයිටර්, පුද්ගලික, ආයෝජන, සමාගමක්, වන, ආරක්ෂක...
# 2  [රොයිටර්, බොරතෙල්, මිල, ඉහළ, යාම, සහ, ආර්ථිකය,...
# 3  [රොයිටර්, කැරලිකාර, මිලීෂියාවකට, යටිතල, පහසුකම...
# 4  [ඉරාක, ලෝක, තෙල්, මිල, වාර්තා, පෙරලීම, සහ, මුද...

# %%
stopwordsreader = open('/kaggle/input/stop-words/stop words.txt', 'r', encoding='utf-8')
reader = csv.reader(stopwordsreader)

swords = []
for row in reader:
    swords.append(row[0])
print(swords)
# Out:
# ['සහ', 'සමග', 'සමඟ', 'අහා', 'ආහ්', 'ආ', 'ඕහෝ', 'අනේ', 'අඳෝ', 'අපොයි', 'අපෝ', 'අයියෝ', 'ආයි', 'ඌයි', 'චී', 'චිහ්', 'චික්', 'හෝ\u200d', 'දෝ', 'දෝහෝ', 'මෙන්', 'සේ', 'වැනි', 'බඳු', 'වන්', 'අයුරු', 'අයුරින්', 'ලෙස', 'වැඩි', 'ශ්\u200dරී', 'හා', 'ය', 'නිසා', 'නිසාවෙන්', 'බවට', 'බව', 'බවෙන්', 'නම්', 'වැඩි', 'සිට', 'දී', 'මහා', 'මහ', 'පමණ', 'පමණින්', 'පමන', 'වන', 'විට', 'විටින්', 'මේ', 'මෙලෙස', 'මෙයින්', 'ඇති', 'ලෙස', 'සිදු', 'වශයෙන්', 'යන', 'සඳහා', 'මගින්', 'හෝ\u200d', 'ඉතා', 'ඒ', 'එම', 'ද', 'අතර', 'විසින්', 'සමග', 'පිළිබඳව', 'පිළිබඳ', 'තුළ', 'බව', 'වැනි', 'මහ', 'මෙම', 'මෙහි', 'මේ', 'වෙත', 'වෙතින්', 'වෙතට', 'වෙනුවෙන්', 'වෙනුවට', 'වෙන', 'ගැන', 'නෑ', 'අනුව', 'නව', 'පිළිබඳ', 'විශේෂ', 'දැනට', 'එහෙන්', 'මෙහෙන්', 'එහේ', 'මෙහේ', 'ම', 'තවත්', 'තව ', 'සහ', 'දක්වා', 'ට', 'ගේ', 'එ', 'ක', 'ක්', 'බවත්', 'බවද', 'මත', 'ඇතුලු', 'ඇතුළු', 'මෙසේ', 'වඩා', 'වඩාත්ම', 'නිති', 'නිතිත්', 'නිතොර', 'නිතර', 'ඉක්බිති', 'දැන්', 'යලි', 'පුන', 'ඉතින්', 'සිට', 'සිටන්', 'පටන්', 'තෙක්', 'දක්වා', 'සා', 'තාක්', 'තුවක්', 'පවා', 'ද', 'හෝ\u200d', 'වත්', 'විනා', 'හැර', 'මිස', 'මුත්', 'කිම', 'කිම්', 'ඇයි', 'මන්ද', 'හෙවත්', 'නොහොත්', 'පතා', 'පාසා', 'ගානෙ', 'තව', 'ඉතා', 'බොහෝ', 'වහා', 'සෙද', 'සැනින්', 'හනික', 'එම්බා', 'එම්බල', 'බොල', 'නම්', 'වනාහි', 'කලී', 'ඉඳුරා', 'අන්න', 'ඔන්න', 'මෙන්න', 'උදෙසා', 'පිණිස', 'සඳහා', 'අරබයා', 'නිසා', 'එනිසා', 'එබැවින්', 'බැවින්', 'හෙයින්', 'සේක්', 'සේක', 'ගැන', 'අනුව', 'පරිදි', 'විට', 'තෙක්', 'මෙතෙක්', 'මේතාක්', 'තුරු', 'තුරා', 'තුරාවට', 'තුලින්', 'නමුත්', 'එනමුත්', 'වස්', 'මෙන්', 'ලෙස', 'පරිදි', 'එහෙත්']

# %%
def remove_stop_words(tokens):
    regex = re.compile(u'[^\u0D80-\u0DFF]', re.UNICODE)
    tokens = [regex.sub('', w) for w in tokens]
    tokens = [c for c in tokens if c not in string.punctuation]
    return tokens

# %%
df['Stopwords Removed (Title)'] = df['Cleaned Title'].apply(lambda x: remove_stop_words(x))
df.head()
# Out:
#    Class Index                                    Title (Sinhala)  \
# 0            3    වෝල් වීදිය නැවතත් ධනාත්මක ආර්ථිකයක් ලබා ගත්තේය.
# 1            3      කාර්ලයිල් වාණිජ අභ්‍යවකාශය දෙස බලයි (රොයිටර්)
# 2            3                                    තෙල් සහ ආර්ථිකය
# 3            3  ඉරාකය ප්‍රධාන දකුණු නල මාර්ගයෙන් (රොයිටර්) තෙල...
# 4            3  එක්සත් ජනපද ආර්ථිකයට (AFP) නව තර්ජනයක් එල්ල කර...
#
#                                Description (Sinhala)  \
# 0  නිව් යෝර්ක් (රොයිටර්) - කෙටි විකුණුම්කරුවන්, ව...
# 1  රොයිටර් - පුද්ගලික ආයෝජන සමාගමක් වන Carlyle Gr...
# 2  රොයිටර් - බොරතෙල් මිල ඉහළ යාම සහ ආර්ථිකය පිළිබ...
# 3  රොයිටර් - කැරලිකාර මිලීෂියාවකට යටිතල පහසුකම්වල...
# 4  AFP - ඉරාක ලෝක තෙල් මිල, වාර්තා පෙරලීම සහ මුදල...
#
#                                        Cleaned Title  \
# 0  [වෝල්, වීදිය, නැවතත්, ධනාත්මක, ආර්ථිකයක්, ලබා,...
# 1  [කාර්ලයිල්, වාණිජ, අභ්යවකාශය, දෙස, බලයි, රොයිටර්]
# 2                                [තෙල්, සහ, ආර්ථිකය]
# 3  [ඉරාකය, ප්රධාන, දකුණු, නල, මාර්ගයෙන්, රොයිටර්,...
# 4  [එක්සත්, ජනපද, ආර්ථිකයට, නව, තර්ජනයක්, එල්ල, ක...
#
#                                  Cleaned Description  \
# 0  [නිව්, යෝර්ක්, රොයිටර්, කෙටි, විකුණුම්කරුවන්, ...
# 1  [රොයිටර්, පුද්ගලික, ආයෝජන, සමාගමක්, වන, ආරක්ෂක...
# 2  [රොයිටර්, බොරතෙල්, මිල, ඉහළ, යාම, සහ, ආර්ථිකය,...
# 3  [රොයිටර්, කැරලිකාර, මිලීෂියාවකට, යටිතල, පහසුකම...
# 4  [ඉරාක, ලෝක, තෙල්, මිල, වාර්තා, පෙරලීම, සහ, මුද...
#
#                            Stopwords Removed (Title)
# 0  [වෝල්, වීදිය, නැවතත්, ධනාත්මක, ආර්ථිකයක්, ලබා,...
# 1  [කාර්ලයිල්, වාණිජ, අභ්යවකාශය, දෙස, බලයි, රොයිටර්]
# 2                                [තෙල්, සහ, ආර්ථිකය]
# 3  [ඉරාකය, ප්රධාන, දකුණු, නල, මාර්ගයෙන්, රොයිටර්,...
# 4  [එක්සත්, ජනපද, ආර්ථිකයට, නව, තර්ජනයක්, එල්ල, ක...

# %%
df['Stopwords Removed (Description)'] = df['Cleaned Description'].apply(lambda x: remove_stop_words(x))
df.head()
# Out:
#    Class Index                                    Title (Sinhala)  \
# 0            3    වෝල් වීදිය නැවතත් ධනාත්මක ආර්ථිකයක් ලබා ගත්තේය.
# 1            3      කාර්ලයිල් වාණිජ අභ්‍යවකාශය දෙස බලයි (රොයිටර්)
# 2            3                                    තෙල් සහ ආර්ථිකය
# 3            3  ඉරාකය ප්‍රධාන දකුණු නල මාර්ගයෙන් (රොයිටර්) තෙල...
# 4            3  එක්සත් ජනපද ආර්ථිකයට (AFP) නව තර්ජනයක් එල්ල කර...
#
#                                Description (Sinhala)  \
# 0  නිව් යෝර්ක් (රොයිටර්) - කෙටි විකුණුම්කරුවන්, ව...
# 1  රොයිටර් - පුද්ගලික ආයෝජන සමාගමක් වන Carlyle Gr...
# 2  රොයිටර් - බොරතෙල් මිල ඉහළ යාම සහ ආර්ථිකය පිළිබ...
# 3  රොයිටර් - කැරලිකාර මිලීෂියාවකට යටිතල පහසුකම්වල...
# 4  AFP - ඉරාක ලෝක තෙල් මිල, වාර්තා පෙරලීම සහ මුදල...
#
#                                        Cleaned Title  \
# 0  [වෝල්, වීදිය, නැවතත්, ධනාත්මක, ආර්ථිකයක්, ලබා,...
# 1  [කාර්ලයිල්, වාණිජ, අභ්යවකාශය, දෙස, බලයි, රොයිටර්]
# 2                                [තෙල්, සහ, ආර්ථිකය]
# 3  [ඉරාකය, ප්රධාන, දකුණු, නල, මාර්ගයෙන්, රොයිටර්,...
# 4  [එක්සත්, ජනපද, ආර්ථිකයට, නව, තර්ජනයක්, එල්ල, ක...
#
#                                  Cleaned Description  \
# 0  [නිව්, යෝර්ක්, රොයිටර්, කෙටි, විකුණුම්කරුවන්, ...
# 1  [රොයිටර්, පුද්ගලික, ආයෝජන, සමාගමක්, වන, ආරක්ෂක...
# 2  [රොයිටර්, බොරතෙල්, මිල, ඉහළ, යාම, සහ, ආර්ථිකය,...
# 3  [රොයිටර්, කැරලිකාර, මිලීෂියාවකට, යටිතල, පහසුකම...
# 4  [ඉරාක, ලෝක, තෙල්, මිල, වාර්තා, පෙරලීම, සහ, මුද...
#
#                            Stopwords Removed (Title)  \
# 0  [වෝල්, වීදිය, නැවතත්, ධනාත්මක, ආර්ථිකයක්, ලබා,...
# 1  [කාර්ලයිල්, වාණිජ, අභ්යවකාශය, දෙස, බලයි, රොයිටර්]
# 2                                [තෙල්, සහ, ආර්ථිකය]
# 3  [ඉරාකය, ප්රධාන, දකුණු, නල, මාර්ගයෙන්, රොයිටර්,...
# 4  [එක්සත්, ජනපද, ආර්ථිකයට, නව, තර්ජනයක්, එල්ල, ක...
#
#                      Stopwords Removed (Description)
# 0  [නිව්, යෝර්ක්, රොයිටර්, කෙටි, විකුණුම්කරුවන්, ...
# 1  [රොයිටර්, පුද්ගලික, ආයෝජන, සමාගමක්, වන, ආරක්ෂක...
# 2  [රොයිටර්, බොරතෙල්, මිල, ඉහළ, යාම, සහ, ආර්ථිකය,...
# 3  [රොයිටර්, කැරලිකාර, මිලීෂියාවකට, යටිතල, පහසුකම...
# 4  [ඉරාක, ලෝක, තෙල්, මිල, වාර්තා, පෙරලීම, සහ, මුද...

# %%
stem_dict = open('/kaggle/input/stem-dictionary/stem_dictionary.txt', "r", encoding='utf-8')
stem_dict = map(lambda s: s.strip(), stem_dict)

stem_dictionary = {}

for s in stem_dict:
    s = s.split("\t")
    stem_dictionary[s[0]] = s[1]

# %%
def stemming_words(tokens):
    for k, v in enumerate(tokens):
        tokens[k] = stem_dictionary.get(v, v)
    tokens = " ".join([c for c in tokens if c not in string.punctuation])
    return tokens

# %%
df['Stemming Words (Title)'] = df['Stopwords Removed (Title)'].apply(lambda x: stemming_words(x))
df.head()
# Out:
#    Class Index                                    Title (Sinhala)  \
# 0            3    වෝල් වීදිය නැවතත් ධනාත්මක ආර්ථිකයක් ලබා ගත්තේය.
# 1            3      කාර්ලයිල් වාණිජ අභ්‍යවකාශය දෙස බලයි (රොයිටර්)
# 2            3                                    තෙල් සහ ආර්ථිකය
# 3            3  ඉරාකය ප්‍රධාන දකුණු නල මාර්ගයෙන් (රොයිටර්) තෙල...
# 4            3  එක්සත් ජනපද ආර්ථිකයට (AFP) නව තර්ජනයක් එල්ල කර...
#
#                                Description (Sinhala)  \
# 0  නිව් යෝර්ක් (රොයිටර්) - කෙටි විකුණුම්කරුවන්, ව...
# 1  රොයිටර් - පුද්ගලික ආයෝජන සමාගමක් වන Carlyle Gr...
# 2  රොයිටර් - බොරතෙල් මිල ඉහළ යාම සහ ආර්ථිකය පිළිබ...
# 3  රොයිටර් - කැරලිකාර මිලීෂියාවකට යටිතල පහසුකම්වල...
# 4  AFP - ඉරාක ලෝක තෙල් මිල, වාර්තා පෙරලීම සහ මුදල...
#
#                                        Cleaned Title  \
# 0  [වෝල්, වීදිය, නැවතත්, ධනාත්මක, ආර්ථිකයක්, ලබා,...
# 1  [කාර්ලයිල්, වාණිජ, අභ්යවකාශය, දෙස, බලයි, රොයිටර්]
# 2                                [තෙල්, සහ, ආර්ථිකය]
# 3  [ඉරාකය, ප්රධාන, දකුණු, නල, මාර්ගයෙන්, රොයිටර්,...
# 4  [එක්සත්, ජනපද, ආර්ථිකයට, නව, තර්ජනයක්, එල්ල, ක...
#
#                                  Cleaned Description  \
# 0  [නිව්, යෝර්ක්, රොයිටර්, කෙටි, විකුණුම්කරුවන්, ...
# 1  [රොයිටර්, පුද්ගලික, ආයෝජන, සමාගමක්, වන, ආරක්ෂක...
# 2  [රොයිටර්, බොරතෙල්, මිල, ඉහළ, යාම, සහ, ආර්ථිකය,...
# 3  [රොයිටර්, කැරලිකාර, මිලීෂියාවකට, යටිතල, පහසුකම...
# 4  [ඉරාක, ලෝක, තෙල්, මිල, වාර්තා, පෙරලීම, සහ, මුද...
#
#                            Stopwords Removed (Title)  \
# 0  [වෝල්, වීදිය, නැවත, ධනාත්මක, ආර්ථිකයක්, ලබා, ග...
# 1  [කාර්ලයිල්, වාණිජ, අභ්යවකාශය, දෙස, බලයි, රොයිටර්]
# 2                                [තෙල්, සහ, ආර්ථිකය]
# 3  [ඉරාක, ප්රධාන, දකුණු, නල, මාර්ගයෙන්, රොයිටර්, ...
# 4  [එක්සත, ජනපද, ආර්ථිකයට, නව, තර්ජනයක්, එල්ල, කර...
#
#                      Stopwords Removed (Description)  \
# 0  [නිව්, යෝර්ක්, රොයිටර්, කෙටි, විකුණුම්කරුවන්, ...
# 1  [රොයිටර්, පුද්ගලික, ආයෝජන, සමාගමක්, වන, ආරක්ෂක...
# 2  [රොයිටර්, බොරතෙල්, මිල, ඉහළ, යාම, සහ, ආර්ථිකය,...
# 3  [රොයිටර්, කැරලිකාර, මිලීෂියාවකට, යටිතල, පහසුකම...
# 4  [ඉරාක, ලෝක, තෙල්, මිල, වාර්තා, පෙරලීම, සහ, මුද...
#
#                               Stemming Words (Title)
# 0       වෝල් වීදිය නැවත ධනාත්මක ආර්ථිකයක් ලබා ගත්තේය
# 1         කාර්ලයිල් වාණිජ අභ්යවකාශය දෙස බලයි රොයිටර්
# 2                                    තෙල් සහ ආර්ථිකය
# 3  ඉරාක ප්රධාන දකුණු නල මාර්ගයෙන් රොයිටර් තෙල් අප...
# 4  එක්සත ජනපද ආර්ථිකයට නව තර්ජනයක් එල්ල කරමින් තෙ...

# %%
df['Stemming Words (Description)'] = df['Stopwords Removed (Description)'].apply(lambda x: stemming_words(x))
df.head()
# Out:
#    Class Index                                    Title (Sinhala)  \
# 0            3    වෝල් වීදිය නැවතත් ධනාත්මක ආර්ථිකයක් ලබා ගත්තේය.
# 1            3      කාර්ලයිල් වාණිජ අභ්‍යවකාශය දෙස බලයි (රොයිටර්)
# 2            3                                    තෙල් සහ ආර්ථිකය
# 3            3  ඉරාකය ප්‍රධාන දකුණු නල මාර්ගයෙන් (රොයිටර්) තෙල...
# 4            3  එක්සත් ජනපද ආර්ථිකයට (AFP) නව තර්ජනයක් එල්ල කර...
#
#                                Description (Sinhala)  \
# 0  නිව් යෝර්ක් (රොයිටර්) - කෙටි විකුණුම්කරුවන්, ව...
# 1  රොයිටර් - පුද්ගලික ආයෝජන සමාගමක් වන Carlyle Gr...
# 2  රොයිටර් - බොරතෙල් මිල ඉහළ යාම සහ ආර්ථිකය පිළිබ...
# 3  රොයිටර් - කැරලිකාර මිලීෂියාවකට යටිතල පහසුකම්වල...
# 4  AFP - ඉරාක ලෝක තෙල් මිල, වාර්තා පෙරලීම සහ මුදල...
#
#                                        Cleaned Title  \
# 0  [වෝල්, වීදිය, නැවතත්, ධනාත්මක, ආර්ථිකයක්, ලබා,...
# 1  [කාර්ලයිල්, වාණිජ, අභ්යවකාශය, දෙස, බලයි, රොයිටර්]
# 2                                [තෙල්, සහ, ආර්ථිකය]
# 3  [ඉරාකය, ප්රධාන, දකුණු, නල, මාර්ගයෙන්, රොයිටර්,...
# 4  [එක්සත්, ජනපද, ආර්ථිකයට, නව, තර්ජනයක්, එල්ල, ක...
#
#                                  Cleaned Description  \
# 0  [නිව්, යෝර්ක්, රොයිටර්, කෙටි, විකුණුම්කරුවන්, ...
# 1  [රොයිටර්, පුද්ගලික, ආයෝජන, සමාගමක්, වන, ආරක්ෂක...
# 2  [රොයිටර්, බොරතෙල්, මිල, ඉහළ, යාම, සහ, ආර්ථිකය,...
# 3  [රොයිටර්, කැරලිකාර, මිලීෂියාවකට, යටිතල, පහසුකම...
# 4  [ඉරාක, ලෝක, තෙල්, මිල, වාර්තා, පෙරලීම, සහ, මුද...
#
#                            Stopwords Removed (Title)  \
# 0  [වෝල්, වීදිය, නැවත, ධනාත්මක, ආර්ථිකයක්, ලබා, ග...
# 1  [කාර්ලයිල්, වාණිජ, අභ්යවකාශය, දෙස, බලයි, රොයිටර්]
# 2                                [තෙල්, සහ, ආර්ථිකය]
# 3  [ඉරාක, ප්රධාන, දකුණු, නල, මාර්ගයෙන්, රොයිටර්, ...
# 4  [එක්සත, ජනපද, ආර්ථිකයට, නව, තර්ජනයක්, එල්ල, කර...
#
#                      Stopwords Removed (Description)  \
# 0  [නිව්, යෝර්ක්, රොයිටර්, කෙටි, විකුණුම්කරුවන්, ...
# 1  [රොයිටර්, පුද්ගලික, ආයෝජන, සමාගමක්, වන, ආරක්ෂක...
# 2  [රොයිටර්, බොරතෙල්, මිල, ඉහළ, යාම, සහ, ආර්ථිකය,...
# 3  [රොයිටර්, කැරලිකාර, මිලීෂියාවකට, යටිතල, පහසුකම...
# 4  [ඉරාක, ලෝක, තෙල්, මිල, වාර්තා, පෙරලීම, සහ, මුද...
#
#                               Stemming Words (Title)  \
# 0       වෝල් වීදිය නැවත ධනාත්මක ආර්ථිකයක් ලබා ගත්තේය
# 1         කාර්ලයිල් වාණිජ අභ්යවකාශය දෙස බලයි රොයිටර්
# 2                                    තෙල් සහ ආර්ථිකය
# 3  ඉරාක ප්රධාන දකුණු නල මාර්ගයෙන් රොයිටර් තෙල් අප...
# 4  එක්සත ජනපද ආර්ථිකයට නව තර්ජනයක් එල්ල කරමින් තෙ...
#
#                         Stemming Words (Description)
# 0  නිව් යෝර්ක් රොයිටර් කෙටි විකුණුම්කරුවන් වෝල් ස...
# 1  රොයිටර් පුද්ගලික ආයෝජන සමාගමක් වන ආරක්ෂක කර්මා...
# 2  රොයිටර් බොරතෙල් මිල ඉහළ යාම සහ ආර්ථිකය පිළිබඳ ...
# 3  රොයිටර් කැරලිකාර මිලීෂියාවකට යටිතල පහසුකම් පහර...
# 4  ඉරාක ලෝක තෙල් මිල වාර්තා පෙරලීම සහ මුදල් පසුම්...

# %%
df.drop_duplicates(subset='Stemming Words (Title)', keep='first', inplace=True)

df.head()
# Out:
#    Class Index                                    Title (Sinhala)  \
# 0            3    වෝල් වීදිය නැවතත් ධනාත්මක ආර්ථිකයක් ලබා ගත්තේය.
# 1            3      කාර්ලයිල් වාණිජ අභ්‍යවකාශය දෙස බලයි (රොයිටර්)
# 2            3                                    තෙල් සහ ආර්ථිකය
# 3            3  ඉරාකය ප්‍රධාන දකුණු නල මාර්ගයෙන් (රොයිටර්) තෙල...
# 4            3  එක්සත් ජනපද ආර්ථිකයට (AFP) නව තර්ජනයක් එල්ල කර...
#
#                                Description (Sinhala)  \
# 0  නිව් යෝර්ක් (රොයිටර්) - කෙටි විකුණුම්කරුවන්, ව...
# 1  රොයිටර් - පුද්ගලික ආයෝජන සමාගමක් වන Carlyle Gr...
# 2  රොයිටර් - බොරතෙල් මිල ඉහළ යාම සහ ආර්ථිකය පිළිබ...
# 3  රොයිටර් - කැරලිකාර මිලීෂියාවකට යටිතල පහසුකම්වල...
# 4  AFP - ඉරාක ලෝක තෙල් මිල, වාර්තා පෙරලීම සහ මුදල...
#
#                                        Cleaned Title  \
# 0  [වෝල්, වීදිය, නැවතත්, ධනාත්මක, ආර්ථිකයක්, ලබා,...
# 1  [කාර්ලයිල්, වාණිජ, අභ්යවකාශය, දෙස, බලයි, රොයිටර්]
# 2                                [තෙල්, සහ, ආර්ථිකය]
# 3  [ඉරාකය, ප්රධාන, දකුණු, නල, මාර්ගයෙන්, රොයිටර්,...
# 4  [එක්සත්, ජනපද, ආර්ථිකයට, නව, තර්ජනයක්, එල්ල, ක...
#
#                                  Cleaned Description  \
# 0  [නිව්, යෝර්ක්, රොයිටර්, කෙටි, විකුණුම්කරුවන්, ...
# 1  [රොයිටර්, පුද්ගලික, ආයෝජන, සමාගමක්, වන, ආරක්ෂක...
# 2  [රොයිටර්, බොරතෙල්, මිල, ඉහළ, යාම, සහ, ආර්ථිකය,...
# 3  [රොයිටර්, කැරලිකාර, මිලීෂියාවකට, යටිතල, පහසුකම...
# 4  [ඉරාක, ලෝක, තෙල්, මිල, වාර්තා, පෙරලීම, සහ, මුද...
#
#                            Stopwords Removed (Title)  \
# 0  [වෝල්, වීදිය, නැවත, ධනාත්මක, ආර්ථිකයක්, ලබා, ග...
# 1  [කාර්ලයිල්, වාණිජ, අභ්යවකාශය, දෙස, බලයි, රොයිටර්]
# 2                                [තෙල්, සහ, ආර්ථිකය]
# 3  [ඉරාක, ප්රධාන, දකුණු, නල, මාර්ගයෙන්, රොයිටර්, ...
# 4  [එක්සත, ජනපද, ආර්ථිකයට, නව, තර්ජනයක්, එල්ල, කර...
#
#                      Stopwords Removed (Description)  \
# 0  [නිව්, යෝර්ක්, රොයිටර්, කෙටි, විකුණුම්කරුවන්, ...
# 1  [රොයිටර්, පුද්ගලික, ආයෝජන, සමාගමක්, වන, ආරක්ෂක...
# 2  [රොයිටර්, බොරතෙල්, මිල, ඉහළ, යාම, සහ, ආර්ථිකය,...
# 3  [රොයිටර්, කැරලිකාර, මිලීෂියාවකට, යටිතල, පහසුකම...
# 4  [ඉරාක, ලෝක, තෙල්, මිල, වාර්තා, පෙරලීම, සහ, මුද...
#
#                               Stemming Words (Title)  \
# 0       වෝල් වීදිය නැවත ධනාත්මක ආර්ථිකයක් ලබා ගත්තේය
# 1         කාර්ලයිල් වාණිජ අභ්යවකාශය දෙස බලයි රොයිටර්
# 2                                    තෙල් සහ ආර්ථිකය
# 3  ඉරාක ප්රධාන දකුණු නල මාර්ගයෙන් රොයිටර් තෙල් අප...
# 4  එක්සත ජනපද ආර්ථිකයට නව තර්ජනයක් එල්ල කරමින් තෙ...
#
#                         Stemming Words (Description)
# 0  නිව් යෝර්ක් රොයිටර් කෙටි විකුණුම්කරුවන් වෝල් ස...
# 1  රොයිටර් පුද්ගලික ආයෝජන සමාගමක් වන ආරක්ෂක කර්මා...
# 2  රොයිටර් බොරතෙල් මිල ඉහළ යාම සහ ආර්ථිකය පිළිබඳ ...
# 3  රොයිටර් කැරලිකාර මිලීෂියාවකට යටිතල පහසුකම් පහර...
# 4  ඉරාක ලෝක තෙල් මිල වාර්තා පෙරලීම සහ මුදල් පසුම්...

# %%
df.drop_duplicates(subset='Stemming Words (Description)', keep='first', inplace=True)

df.head()
# Out:
#    Class Index                                    Title (Sinhala)  \
# 0            3    වෝල් වීදිය නැවතත් ධනාත්මක ආර්ථිකයක් ලබා ගත්තේය.
# 1            3      කාර්ලයිල් වාණිජ අභ්‍යවකාශය දෙස බලයි (රොයිටර්)
# 2            3                                    තෙල් සහ ආර්ථිකය
# 3            3  ඉරාකය ප්‍රධාන දකුණු නල මාර්ගයෙන් (රොයිටර්) තෙල...
# 4            3  එක්සත් ජනපද ආර්ථිකයට (AFP) නව තර්ජනයක් එල්ල කර...
#
#                                Description (Sinhala)  \
# 0  නිව් යෝර්ක් (රොයිටර්) - කෙටි විකුණුම්කරුවන්, ව...
# 1  රොයිටර් - පුද්ගලික ආයෝජන සමාගමක් වන Carlyle Gr...
# 2  රොයිටර් - බොරතෙල් මිල ඉහළ යාම සහ ආර්ථිකය පිළිබ...
# 3  රොයිටර් - කැරලිකාර මිලීෂියාවකට යටිතල පහසුකම්වල...
# 4  AFP - ඉරාක ලෝක තෙල් මිල, වාර්තා පෙරලීම සහ මුදල...
#
#                                        Cleaned Title  \
# 0  [වෝල්, වීදිය, නැවතත්, ධනාත්මක, ආර්ථිකයක්, ලබා,...
# 1  [කාර්ලයිල්, වාණිජ, අභ්යවකාශය, දෙස, බලයි, රොයිටර්]
# 2                                [තෙල්, සහ, ආර්ථිකය]
# 3  [ඉරාකය, ප්රධාන, දකුණු, නල, මාර්ගයෙන්, රොයිටර්,...
# 4  [එක්සත්, ජනපද, ආර්ථිකයට, නව, තර්ජනයක්, එල්ල, ක...
#
#                                  Cleaned Description  \
# 0  [නිව්, යෝර්ක්, රොයිටර්, කෙටි, විකුණුම්කරුවන්, ...
# 1  [රොයිටර්, පුද්ගලික, ආයෝජන, සමාගමක්, වන, ආරක්ෂක...
# 2  [රොයිටර්, බොරතෙල්, මිල, ඉහළ, යාම, සහ, ආර්ථිකය,...
# 3  [රොයිටර්, කැරලිකාර, මිලීෂියාවකට, යටිතල, පහසුකම...
# 4  [ඉරාක, ලෝක, තෙල්, මිල, වාර්තා, පෙරලීම, සහ, මුද...
#
#                            Stopwords Removed (Title)  \
# 0  [වෝල්, වීදිය, නැවත, ධනාත්මක, ආර්ථිකයක්, ලබා, ග...
# 1  [කාර්ලයිල්, වාණිජ, අභ්යවකාශය, දෙස, බලයි, රොයිටර්]
# 2                                [තෙල්, සහ, ආර්ථිකය]
# 3  [ඉරාක, ප්රධාන, දකුණු, නල, මාර්ගයෙන්, රොයිටර්, ...
# 4  [එක්සත, ජනපද, ආර්ථිකයට, නව, තර්ජනයක්, එල්ල, කර...
#
#                      Stopwords Removed (Description)  \
# 0  [නිව්, යෝර්ක්, රොයිටර්, කෙටි, විකුණුම්කරුවන්, ...
# 1  [රොයිටර්, පුද්ගලික, ආයෝජන, සමාගමක්, වන, ආරක්ෂක...
# 2  [රොයිටර්, බොරතෙල්, මිල, ඉහළ, යාම, සහ, ආර්ථිකය,...
# 3  [රොයිටර්, කැරලිකාර, මිලීෂියාවකට, යටිතල, පහසුකම...
# 4  [ඉරාක, ලෝක, තෙල්, මිල, වාර්තා, පෙරලීම, සහ, මුද...
#
#                               Stemming Words (Title)  \
# 0       වෝල් වීදිය නැවත ධනාත්මක ආර්ථිකයක් ලබා ගත්තේය
# 1         කාර්ලයිල් වාණිජ අභ්යවකාශය දෙස බලයි රොයිටර්
# 2                                    තෙල් සහ ආර්ථිකය
# 3  ඉරාක ප්රධාන දකුණු නල මාර්ගයෙන් රොයිටර් තෙල් අප...
# 4  එක්සත ජනපද ආර්ථිකයට නව තර්ජනයක් එල්ල කරමින් තෙ...
#
#                         Stemming Words (Description)
# 0  නිව් යෝර්ක් රොයිටර් කෙටි විකුණුම්කරුවන් වෝල් ස...
# 1  රොයිටර් පුද්ගලික ආයෝජන සමාගමක් වන ආරක්ෂක කර්මා...
# 2  රොයිටර් බොරතෙල් මිල ඉහළ යාම සහ ආර්ථිකය පිළිබඳ ...
# 3  රොයිටර් කැරලිකාර මිලීෂියාවකට යටිතල පහසුකම් පහර...
# 4  ඉරාක ලෝක තෙල් මිල වාර්තා පෙරලීම සහ මුදල් පසුම්...

# %%
df.drop(df.columns[[1, 2, 3, 4, 5, 6]], axis=1, inplace=True)
df.head()
# Out:
#    Class Index                             Stemming Words (Title)  \
# 0            3       වෝල් වීදිය නැවත ධනාත්මක ආර්ථිකයක් ලබා ගත්තේය
# 1            3         කාර්ලයිල් වාණිජ අභ්යවකාශය දෙස බලයි රොයිටර්
# 2            3                                    තෙල් සහ ආර්ථිකය
# 3            3  ඉරාක ප්රධාන දකුණු නල මාර්ගයෙන් රොයිටර් තෙල් අප...
# 4            3  එක්සත ජනපද ආර්ථිකයට නව තර්ජනයක් එල්ල කරමින් තෙ...
#
#                         Stemming Words (Description)
# 0  නිව් යෝර්ක් රොයිටර් කෙටි විකුණුම්කරුවන් වෝල් ස...
# 1  රොයිටර් පුද්ගලික ආයෝජන සමාගමක් වන ආරක්ෂක කර්මා...
# 2  රොයිටර් බොරතෙල් මිල ඉහළ යාම සහ ආර්ථිකය පිළිබඳ ...
# 3  රොයිටර් කැරලිකාර මිලීෂියාවකට යටිතල පහසුකම් පහර...
# 4  ඉරාක ලෝක තෙල් මිල වාර්තා පෙරලීම සහ මුදල් පසුම්...

# %%
df.columns = ['ClassIndex', 'Stemming Words (Title)', 'Stemming Words (Description)']

# %%
df['Stemming Words'] = df['Stemming Words (Title)'] + " " + df['Stemming Words (Description)']

df.head()
# Out:
#    ClassIndex                             Stemming Words (Title)  \
# 0           3       වෝල් වීදිය නැවත ධනාත්මක ආර්ථිකයක් ලබා ගත්තේය
# 1           3         කාර්ලයිල් වාණිජ අභ්යවකාශය දෙස බලයි රොයිටර්
# 2           3                                    තෙල් සහ ආර්ථිකය
# 3           3  ඉරාක ප්රධාන දකුණු නල මාර්ගයෙන් රොයිටර් තෙල් අප...
# 4           3  එක්සත ජනපද ආර්ථිකයට නව තර්ජනයක් එල්ල කරමින් තෙ...
#
#                         Stemming Words (Description)  \
# 0  නිව් යෝර්ක් රොයිටර් කෙටි විකුණුම්කරුවන් වෝල් ස...
# 1  රොයිටර් පුද්ගලික ආයෝජන සමාගමක් වන ආරක්ෂක කර්මා...
# 2  රොයිටර් බොරතෙල් මිල ඉහළ යාම සහ ආර්ථිකය පිළිබඳ ...
# 3  රොයිටර් කැරලිකාර මිලීෂියාවකට යටිතල පහසුකම් පහර...
# 4  ඉරාක ලෝක තෙල් මිල වාර්තා පෙරලීම සහ මුදල් පසුම්...
#
#                                       Stemming Words
# 0  වෝල් වීදිය නැවත ධනාත්මක ආර්ථිකයක් ලබා ගත්තේය න...
# 1  කාර්ලයිල් වාණිජ අභ්යවකාශය දෙස බලයි රොයිටර් රොය...
# 2  තෙල් සහ ආර්ථිකය රොයිටර් බොරතෙල් මිල ඉහළ යාම සහ...
# 3  ඉරාක ප්රධාන දකුණු නල මාර්ගයෙන් රොයිටර් තෙල් අප...
# 4  එක්සත ජනපද ආර්ථිකයට නව තර්ජනයක් එල්ල කරමින් තෙ...

# %%
df.drop(df.columns[[1, 2]], axis=1, inplace=True)
df.head()
# Out:
#    ClassIndex                                     Stemming Words
# 0           3  වෝල් වීදිය නැවත ධනාත්මක ආර්ථිකයක් ලබා ගත්තේය න...
# 1           3  කාර්ලයිල් වාණිජ අභ්යවකාශය දෙස බලයි රොයිටර් රොය...
# 2           3  තෙල් සහ ආර්ථිකය රොයිටර් බොරතෙල් මිල ඉහළ යාම සහ...
# 3           3  ඉරාක ප්රධාන දකුණු නල මාර්ගයෙන් රොයිටර් තෙල් අප...
# 4           3  එක්සත ජනපද ආර්ථිකයට නව තර්ජනයක් එල්ල කරමින් තෙ...

# %%
df.isnull().sum()
# Out:
# ClassIndex        0
# Stemming Words    0
# dtype: int64

# %%
df['ClassIndex'].value_counts()
# Out:
# 1    29810
# 2    28599
# 3    27876
# 4    26380
# Name: ClassIndex, dtype: int64

# %%
df.shape
# Out:
# (112665, 2)

# %%
vectorizer = CountVectorizer()

X = vectorizer.fit_transform(df['Stemming Words'])

# %%
print(X.shape)
# Out:
# (112665, 6379)

# %%
X[0].toarray()
# Out:
# array([[0, 0, 0, ..., 0, 0, 0]])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, df['ClassIndex'], test_size = 0.2,random_state = 42)

# %%
from sklearn.metrics import f1_score, accuracy_score # mectric that use

# %%
model = MultinomialNB()

model.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
review = 'ශ්‍රී ලංකාව හා දකුණු අප්‍රිකාව අතර අද(10) පැවැත්වීමට නියමිත පළමු පන්දුවාර 20යි 20 ක්‍රිකට් තරගය ක්‍රීඩා කිරීමේ අවස්ථාව කුසල් ජනිත් පෙරේරාට අහිමි වී ඇති බව වාර්තා වනවා.'

commenttype = model.predict(vectorizer.transform([review]))[0]

if commenttype == '1':
    print('World Comment')
elif commenttype == '2':
     print('Sport Comment')
elif commenttype == '3':
     print('Business Comment')
elif commenttype == '4':
     print('Science Comment')
else:
    print('Other Comment')
# Out:
# Other Comment
